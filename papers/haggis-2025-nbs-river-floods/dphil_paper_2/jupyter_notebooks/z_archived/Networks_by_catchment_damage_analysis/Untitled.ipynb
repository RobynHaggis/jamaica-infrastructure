# %%
import pandas as pd
from pathlib import Path

# Define the base path (update this to your actual base path)
base_path = Path("/Users/robynhaggis/Documents/Geospatial_analysis")
direct_damages_folder = base_path / "Results/direct_damages_summary"

# Construct the full path to the parquet file
file_path = direct_damages_folder / "electricity_network_v3.1_edges_damages.parquet"

# Option 1: Set pandas option to display all columns
pd.set_option('display.max_columns', None)
display("All columns in the DataFrame:")
display(df.columns.tolist())

# Option 2: Filter and display only columns that contain the word "fluvial"
fluvial_columns = [col for col in df.columns if 'fluvial' in col.lower()]
display("\nColumns containing 'fluvial':")
display(fluvial_columns)
