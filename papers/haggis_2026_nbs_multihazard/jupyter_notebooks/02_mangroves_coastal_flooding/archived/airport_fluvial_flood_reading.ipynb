# %%
import os
from pathlib import Path
import geopandas
import pandas
import matplotlib.pyplot as plt
import rasterio
import sys, pathlib
sys.path.append(str(pathlib.Path("/Users/robynhaggis/Documents/Geospatial_analysis/dphil_papers/scripts/analysis")))
import analysis_utils
from analysis_utils import *

# %%
base_path = Path("/Users/robynhaggis/Documents/Geospatial_analysis/dphil_papers")

# %%
airport_coastal_flood_path = "/Users/robynhaggis/Documents/Geospatial_analysis/dphil_papers/dphil_common_cross_cutting/common_processed_data/asset_hazard_intersections_from_february_was_labelled_archived/fluvial/airport_with_fluvial.parquet"
airport_coastal_flood = gpd.read_parquet(airport_coastal_flood_path)

# %%
airport_coastal_flood.plot()
